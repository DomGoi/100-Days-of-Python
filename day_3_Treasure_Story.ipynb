# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure. Good luck")

print("You have just woken up on some sort of tropical island.")
print("The wind is blowing, and the sun is shining, yet the ocean waves seem to be calm.")

input_1=input("You decide to: go for a swim in the ocean (type: swim) or look around for some food (type:look)").lower()
if input_1 == 'swim':
  input_1a=input("The water is warm, and you decide to swim further from the shore. Suddenly you feel that something is starting to drag you underwater. What do you do: you fight furiously throwing punches under the water and struggling (type:'fight') or do you give up and let your body sink (type:'sunk')").lower()
  if input_1a == 'fight':
    input_1aa=input('You fight as hard as you can. Out of the sudden you are let free and swim fast to the shore. There is something weird in the water, do you inspect it? Yes or no?').lower()
    if input_1aa == 'yes':
      input_1ab=input('In the water, you can see a floating yellow jelly-like substance. Yes, it is a jellyfish. Not a very dangerous one... not yet. In the distance, you spot a few other yellow comrades, who swiftly swim away when being spotted. This night you will not sleep peacefully (type: war) or will you (type: peace)?').lower()
      if input_1ab =='war':
        input_1ac=input('You prepare for the jellyfishe attack, which indeed proceed that night. You have managed to killed few of them, but to your suprise they have an advanced technology allowing them to use air, and walk on land in some sort of seeweed mechs. You run away wounded, and pass out from dehydration somewhere in the jungle. When you wake up you see some sailors asking you what happend? Do you tell them (type:tell) or keep it to yourself, it was a weird dream (type;dream)? ').lower()
        if input_1ac == 'dream':
          print("You keep it to yourself thinking it was just some delusion. But it was not, jellyfishes were preparing an uprising to revenge all their commanders eaten by people, thrown by kids, or simply used as an amusement in the aquariums around the world. One day they emerged from the sea everywhere with guns and started attacking humans. Since people didn't know they had lost and became slaves and pets to their overlords Jellyfishes.")
          print('All hail jellyfishes, the greatest form of life!')
        elif input_1ac == 'tell':
          print('Thanks to you people could prepare for that awful war between humans and jellyfishes which lasted years. Many lives have been taken, but finally we have won. By going to space, starting new civilation on the moon and nuking the earth.')
          print('Yay, we did it. The science is indeed a real treasure')
      elif input_1ab =='peace':
        print("You went to sleep that night... forever. You were murdered as revenge for killed jellyfish by their comrades.")
      else:
        print('You have slowly become insane, since that night you have started to think about jellyfish revenge, which would lead to an uprising and nuclear war in the big scheme of things (what a ridiculous idea). When you were rescued by some sailors they brought you to London where you were submitted to the psychiatric ward.')
        print('Well, at least you got some free housing...')
    elif input_1aa == 'no':
      print('Great, you just dodged the nuclear warfare which would take billions of lives and wreck havoc.')
      print('Enjoy your treasure of peaceful life.')

  elif input_1a =='sunk':
    input_1a2=input('You slowly sink, vision gets darker as the last molecules of oxygen are being used. When suddenly something grubs you and puts some sort of aqualung on you. Now you can freely breathe. You feel tentacles wrapping around you while wondering what is going on you see the squid with full make-up and some fishnet stocking. It is flirting with you. Do you flirt back (type: flirt) or do you tell the squidmaid she is not your type (type: reject)?').lower()
    if input_1a2== 'flirt':
      input_1a3=input('Squidmaid seems to reciprocate the feeling. You both go on a date and spend together wonderful night together. You grew fond of each other. You plan to merry her. After a few weeks, you meet her parents, they have only one question before the marriage. Do you like seafood? Yes or no? ').lower()
      if input_1a3 == 'yes':
        print('Well... They are not happy... They made a dinner out of you. Game over sorry.')
        print( 'The only treasure is your taste in seaweed stew served at the squidmaid family dinner. Sorry.')
      elif input_1a3 == 'no':
        print('You get the blessing of squidmaid parents. After a few weeks, you have the most memorable wedding at the Krusty Krab in the bikini bottom, her cousin Squidward was thrown out after he played some music but besides that it was great. You had some monstrous babies which were genetic mutations between mermaids, squid, and humans. But you are proud of them cause they do their best and so do you as a parent.')
        print(' You have discovered the treasure in the form of true love. Awwww.')
      else:
        print('Ha, a joke on you squidmaid parents were nice to you and learned just a bit of human language. They did not understand your answer.')
        print('You are adopted as a funny pet by squid family. Since your barks are so cute.')
    elif input_1a2== 'reject':
      print('Squidmaid take the mysterious machine which was giving you oxygen and run away inking everywhere. You die.')
      print('Game Over.')
    else:
      print('Squidmaid has no idea what you did. You start to explain your concept. She thinks it is interesting. You become friends and spend many years together, you marry a pufferfish, and she marries a shark. Your families travel together around the ocean until the end of your days.')
      print("The real treasure was friendship all along.")
  else:
    inpu_broken=input('Great you have broken the game, are you proud of yourself? Yes or No?').lower()
    if inpu_broken == 'yes':
      print('Since you have such a high self-esteem you are the most valuable (the real) treasure. Good job!')
      print('Thank you for playing.')
    if inpu_broken == 'no':
      print('Good, you broke the game >:[')
      print('Thank you for playing, try again... please do not break it again. Please.')
    else:
      print('I see you are a pure chaos.')
      print('Your treasure is command to go watch the Dark Knight and enjoy the Joker. Thank you for playing.')


elif input_1 == 'look':
  input_yn=input("You wander around the beach looking for some type of food, near your bare foot you spot a small crab dancing. Do you try to catch it? Type yes or no.").lower()
  if input_yn == 'yes':
    input_wound=input("As you reach for the small crab he swiftly *snip* *snap* your finger, grunts (yes they can grunt), and crab away, leaving you with nasty wound. You thought about washing it with ocean water (type:'water') or just ignore it (type:'ignore').").lower()
    if input_wound == 'ignore':
      print("Great... you die from tetanus.")
    elif input_wound == 'water':
      input2_1=input("As you wash your wound with salt water, you spot baby shark. Are you afraid? Type yes or no.").lower()
      if input2_1 == 'no':
        input2_2=input('The shark come to you, and lick your wound. This magically heals them, you are surprised but the shark stands on its fins and starts to tell you that he is a licensed doctor, and he would like to be your doctor forever, for only 9,99$ a month. Do you take the offer (type: offer) or not (type: not)?').lower()
        if input2_2 == 'offer':
          print('You will never be sick again, adittionally it has appeared that the shark doctor is pretty dang good and can heal all type of cancer and mental illneses.')
          print(" Your treasure is health.")
        elif input2_2 == 'not':
          print("The shark swim away and you never see him again.")
          print('You die from cancer, game over.')
        else:
          print('You have confused the shark doctor and he is sad now.')
          print('Why did you do this?')
      elif input2_1 == 'yes':
        print('Your wound is getting worse. After some time you need to amputate your foot. And all of a sudden it appeared you are in the Saw movie tropic edition and you are set free.')
        print('That was a bit of a twisted ending.')
      else:
        print('You are confused... What are you doing?')
        print('No for real... WHAT ARE YOU DOING? WHO ARE YOU?')
    else:
      print("Trying to be creative are we? You die from tetanus.")
  if input_yn == 'no':
    input_3=input('You proceed to walk along the beach and all of a sudden you hear some barks. Do you follow the barks (type: bark) or do you stay focused on the food search mission (type: food)?').lower()
    if input_3 == 'food':
      cave=input('You walk for hours, but all of a sudden you walk into some cave. Where numerous cavemen seat at the big table with tons, like a TON of food. One of the grunts at you, do you grunt back (type:yes) or stay silent (type: no)').lower()
      if cave == 'yes':
        print('Cavemens give you all the food and you are never hungry again. You ate all the best food for your whole life for FREE.')
        print('Treasure is the best food for FREE.')
      elif cave == 'no':
        print('You are being thrown out of the party for the horrid manners of yours.')
        print('Learn some manners and come back. For now, the game is over.')
      else:
        print('You are ignored, sorry.')
    elif input_3 == 'bark':
      print('You have found a friendly dog farm.')
      print('Your treasure is fluffiness.')
    else:
      print('You disappear. Magic trick.')
      print("TaDaa")

else:
  print("You have decided to do anything else. You die from hunger ... and tetanus (because your GM says so).")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
