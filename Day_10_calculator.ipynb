# %%
logo = """
 _____________________
|  _________________  |
| | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
| |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
|  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
| | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
| |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
| | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
| |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
| | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
| |___|___|___| |___| | | |              | || |              | || |              | || |              | |
| | . | 0 | = | | / | | | '--------------' || '--------------' || '--------------' || '--------------' |
| |___|___|___| |___| |  '----------------'  '----------------'  '----------------'  '----------------'
|_____________________|
"""

print(logo)

def add(first, second):
    return first + second

def subtract(first, second):
    return first - second

def multiply(first, second):
    return first * second

def divide(first, second):
    return first / second

def exponent(first,second):
    return first**second

def square(first,second):
  return first

oper = {
    "+": add,
    "-": subtract,
    "*": multiply,
    "/": divide,
    "**":exponent
}

con_1 = True


first = float(input("What's the first number?"))

for i in oper:
    print(i)

operations = input("Pick an operation from the line above:")
second = float(input("What's the next number?"))

calculation_func = oper[operations]
answer = calculation_func(first, second)

print(f'{float(first)} {operations} {float(second)} = {round(answer,2)}')

restart = input(f"Type 'y' to continue calculating with {round(answer,2)}, or type 'n' to exit: ").lower().strip()

while con_1:

    if restart == 'y':
        operations = input("Pick an operation from the line above:")
        next_num = float(input("What's the next number?"))
        calculation_func = oper[operations]
        answer = calculation_func(answer, next_num)
        print(f'{float(first)} {operations} {float(second)} = {round(answer,2)}')
        restart = input(f"Type 'y' to continue calculating with {round(answer,2)}, or type 'n' to exit: ").lower().strip()
    else:
        print("Goodbye")
        break
# Out:
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# ...
